# %%
#%cd /content/drive/MyDrive/Project
#%ls
#!git clone https://github.com/SCLBD/DeepfakeBench.git

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
my_path = '/content/Packages'
save_path = '/content/drive/MyDrive/Project/DeepfakeBench' ## 패키지가 저장될 경로
#os.symlink(save_path, my_path)
sys.path.insert(0, my_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터를 딕셔너리 형태로 저장
data = {
    'Type': ['Naive Meso4', 'Naive MesoIncep', 'Naive CNN-Aug', 'Naive Xception', 'Naive EfficientB4',
             'Spatial Capsule', 'Spatial FWA', 'Spatial X-ray', 'Spatial FFD', 'Spatial CORE',
             'Spatial Recce', 'Spatial UCF'],
    'FF-c23': [0.6077, 0.7583, 0.8493, 0.9637, 0.9567, 0.8421, 0.8765, 0.9592, 0.9624, 0.9638, 0.9621, 0.9705],
    'FF-c40': [0.5920, 0.7278, 0.7846, 0.8261, 0.8150, 0.7040, 0.7357, 0.7925, 0.8237, 0.8194, 0.8190, 0.8399],
    'FF-DF': [0.6771, 0.8542, 0.9048, 0.9799, 0.9757, 0.8669, 0.9210, 0.9794, 0.9803, 0.9787, 0.9797, 0.9883],
    'FF-F2F': [0.6170, 0.8087, 0.8788, 0.9785, 0.9758, 0.8634, 0.9000, 0.9872, 0.9784, 0.9803, 0.9779, 0.9840],
    'FF-FS': [0.5946, 0.7421, 0.9026, 0.9833, 0.9797, 0.8734, 0.8843, 0.9871, 0.9853, 0.9823, 0.9785, 0.9896],
    'FF-NT': [0.5701, 0.6517, 0.7313, 0.9385, 0.9308, 0.7804, 0.8120, 0.9290, 0.9306, 0.9339, 0.9357, 0.9441],
    'CDFv1': [0.7358, 0.7366, 0.7420, 0.7794, 0.7909, 0.7909, 0.7897, 0.7093, 0.7840, 0.7798, 0.7677, 0.7793],
    'CDFv2': [0.6091, 0.6966, 0.7027, 0.7365, 0.7487, 0.7472, 0.6680, 0.6786, 0.7435, 0.7428, 0.7319, 0.7527],
    'DF-1.0': [0.9113, 0.9233, 0.7993, 0.8341, 0.8330, 0.9107, 0.9334, 0.5531, 0.8609, 0.8475, 0.7985, 0.8241],
    'DFD': [0.5481, 0.6069, 0.6464, 0.8163, 0.8148, 0.6841, 0.7403, 0.7655, 0.8024, 0.8018, 0.8119, 0.8074],
    'DFDC': [0.5560, 0.6226, 0.6361, 0.7077, 0.6955, 0.6465, 0.6132, 0.6326, 0.7029, 0.7049, 0.7133, 0.7191],
    'DFDCP': [0.5994, 0.7561, 0.6170, 0.7374, 0.7283, 0.6568, 0.6375, 0.6942, 0.7426, 0.7341, 0.7419, 0.7594],
    'Fsh': [0.5660, 0.6438, 0.5985, 0.6249, 0.6162, 0.6465, 0.5551, 0.6553, 0.6056, 0.6032, 0.6095, 0.6462],
    'UADFV': [0.7150, 0.9049, 0.8739, 0.9379, 0.9472, 0.9078, 0.8539, 0.8989, 0.9450, 0.9412, 0.9446, 0.9528]
}

# 데이터프레임 생성
df = pd.DataFrame(data)

within_domain_datasets = ['FF-c23', 'FF-c40', 'FF-DF', 'FF-F2F', 'FF-FS', 'FF-NT']

# Cross Domain 데이터셋
cross_domain_datasets = ['CDFv1', 'CDFv2', 'DF-1.0', 'DFD', 'DFDC', 'DFDCP', 'Fsh', 'UADFV']

plt.figure(figsize=(12, 6))  # 전체 그림 크기 설정

# Within Domain 꺾은선 그래프
for dataset in within_domain_datasets:
    plt.plot(data['Type'], df[dataset], marker='o', linestyle='-', color='blue', linewidth=2, label=f'Within: {dataset}')

# Cross Domain 꺾은선 그래프
for dataset in cross_domain_datasets:
    plt.plot(data['Type'], df[dataset], marker='x', linestyle='--', color='red', linewidth=2, label=f'Cross: {dataset}')

# 제목과 축 설정
plt.title('Within and Cross Domain Evaluation')
plt.xlabel('models')
plt.xticks(fontsize=8, rotation=45)
plt.ylabel('average AUC')
plt.legend()
plt.show()
# # Within Domain 꺾은선 그래프
# plt.figure(figsize=(12, 6))
# for dataset in within_domain_datasets:
#     plt.plot(data['Type'], df[dataset], marker='o', label=dataset)
# plt.title('Within Domain Evaluation')
# plt.xlabel('Index')
# plt.xticks(fontsize=8, rotation=45)
# plt.ylabel('Value')
# plt.legend()
# plt.show()

# # Cross Domain 꺾은선 그래프
# plt.figure(figsize=(12, 6))
# for dataset in cross_domain_datasets:
#     plt.plot(data['Type'], df[dataset], marker='o', label=dataset)
# plt.xticks(fontsize=8, rotation=45)
# plt.title('Cross Domain Evaluation')
# plt.xlabel('models')
# plt.ylabel('average AUC')
# plt.legend()
# plt.show()

# %%
import condacolab
condacolab.install()
condacolab.check()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-17fb650981d0> in <cell line: 1>()
# ----> 1 import condacolab
#       2 condacolab.install()
#       3 condacolab.check()
#
# ModuleNotFoundError: No module named 'condacolab'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import sys
sys.path
# Out:
# ['/content/Packages',
#  '/content',
#  '/env/python',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '',
#  '/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.10/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# %cd /content/drive/MyDrive/Project/DeepfakeBench
# !sudo apt-get install tree
# !tree
# Out:
# /content/drive/.shortcut-targets-by-id/1G2cdVmYKHKDsw8sItqkKcykT_fs7die1/Project/DeepfakeBench
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 0s (140 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# ...

# %%
# !conda create -n DeepfakeBench python=3.7.2
# !conda activate DeepfakeBench
# !sh install.sh
# Out:
# /bin/bash: line 1: conda: command not found
# /bin/bash: line 1: conda: command not found
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 42.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.86 requires numpy>=1.24.1, but you have numpy 1.21.5 which is incompatible.
# cudf-cu12 24.4.1 requires numpy<2.0a0,>=1.23, but you have numpy 1.21.5 which is incompatible.
# flax 0.8.3 requires numpy>=1.22, but you have numpy 1.21.5 which is incompatible.
# jax 0.4.26 requires numpy>=1.22, but you have numpy 1.21.5 which is incompatible.
# jaxlib 0.4.26+cuda12.cudnn89 requires numpy>=1.22, but you have numpy 1.21.5 which is incompatible.
# ...

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')

my_path = '/content/package'
save_path = '/content/drive/MyDrive/Colab Notebooks/package' ## 패키지가 저장될 경로

os.symlink(save_path, my_path)
sys.path.insert(0, my_path)
