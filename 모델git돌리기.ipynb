# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/Purdue-M2/Fairness-Generalization.git
# Out:
# Cloning into 'Fairness-Generalization'...
# remote: Enumerating objects: 86, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 86 (delta 14), reused 3 (delta 0), pack-reused 58
# Receiving objects: 100% (86/86), 249.08 MiB | 13.17 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# Updating files: 100% (46/46), done.

# %%
# %ls
# %cd /content/drive/MyDrive/Project
# %ls
# Out:
# drive/  sample_data/
# /content/drive/.shortcut-targets-by-id/1G2cdVmYKHKDsw8sItqkKcykT_fs7die1/Project
#  DDPM.ipynb
#  Fairness-Generalization/
#  GeneratedImages/
# 'GROUP28_The generalization challenge in deepfake image detection on human faces using generative adversarial networks (GANs).pdf'
#  Miniconda3-py37_4.9.2-Linux-x86_64.sh
#  Miniconda3-py37_4.9.2-Linux-x86_64.sh.1
#  real_vs_fake/
# 'Reference Paper'/
#  Report.gdoc
#  requirements.txt
#  Stable_Diffusion.ipynb
#  temporal_ppt.gslides
#  test/
#  train/
#  valid/
# 'Vit(384).ipynb'
#  Vit.ipynb
#  ViXNet_Scaling.ipynb
#  계획.gsheet
#  디디피엠.ipynb
#  모델git돌리기.ipynb
#  회의록.gdoc

# %%
# !conda create -n FairnessDeepfake python=3.9.0
# !conda activate FairnessDeepfake
# !pip install -r requirements.txt
# Out:
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/FairnessDeepfake
#
#   added / updated specs:
#     - python=3.9.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     ca-certificates-2024.3.11  |       h06a4308_0         127 KB
#     ld_impl_linux-64-2.38      |       h1181459_1         654 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
#     libgomp-11.2.0             |       h1234567_1         474 KB
#     libstdcxx-ng-11.2.0        |       h1234567_1         4.7 MB
#     ncurses-6.4                |       h6a678d5_0         914 KB
#     openssl-1.1.1w             |       h7f8727e_0         3.7 MB
#     pip-24.0                   |   py39h06a4308_0         2.6 MB
#     python-3.9.0               |       hdb3f193_2        18.1 MB
#     readline-8.2               |       h5eee18b_0         357 KB
#     setuptools-69.5.1          |   py39h06a4308_0        1003 KB
#     sqlite-3.45.3              |       h5eee18b_0         1.2 MB
#     tk-8.6.14                  |       h39e8969_0         3.4 MB
#     tzdata-2024a               |       h04d1e81_0         116 KB
#     wheel-0.43.0               |   py39h06a4308_0         109 KB
#     xz-5.4.6                   |       h5eee18b_1         643 KB
#     zlib-1.2.13                |       h5eee18b_1         111 KB
#     ------------------------------------------------------------
#                                            Total:        43.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2024.3.11-h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.38-h1181459_1
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1w-h7f8727e_0
#   pip                pkgs/main/linux-64::pip-24.0-py39h06a4308_0
#   python             pkgs/main/linux-64::python-3.9.0-hdb3f193_2
#   readline           pkgs/main/linux-64::readline-8.2-h5eee18b_0
#   setuptools         pkgs/main/linux-64::setuptools-69.5.1-py39h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.45.3-h5eee18b_0
#   tk                 pkgs/main/linux-64::tk-8.6.14-h39e8969_0
#   tzdata             pkgs/main/noarch::tzdata-2024a-h04d1e81_0
#   wheel              pkgs/main/linux-64::wheel-0.43.0-py39h06a4308_0
#   xz                 pkgs/main/linux-64::xz-5.4.6-h5eee18b_1
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_1
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# xz-5.4.6             | 643 KB    | : 100% 1.0/1 [00:00<00:00,  2.91it/s]
# zlib-1.2.13          | 111 KB    | : 100% 1.0/1 [00:00<00:00,  5.56it/s]
# ld_impl_linux-64-2.3 | 654 KB    | : 100% 1.0/1 [00:00<00:00,  4.94it/s]
# pip-24.0             | 2.6 MB    | : 100% 1.0/1 [00:00<00:00,  2.64it/s]
# readline-8.2         | 357 KB    | : 100% 1.0/1 [00:00<00:00,  5.23it/s]
# openssl-1.1.1w       | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.31it/s]
# tzdata-2024a         | 116 KB    | : 100% 1.0/1 [00:00<00:00,  4.24it/s]
# tk-8.6.14            | 3.4 MB    | : 100% 1.0/1 [00:00<00:00,  3.25it/s]
# ca-certificates-2024 | 127 KB    | : 100% 1.0/1 [00:00<00:00,  5.31it/s]
# libstdcxx-ng-11.2.0  | 4.7 MB    | : 100% 1.0/1 [00:00<00:00,  2.46it/s]
# wheel-0.43.0         | 109 KB    | : 100% 1.0/1 [00:00<00:00,  5.02it/s]
# sqlite-3.45.3        | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  4.76it/s]
# setuptools-69.5.1    | 1003 KB   | : 100% 1.0/1 [00:00<00:00,  3.73it/s]
# python-3.9.0         | 18.1 MB   | : 100% 1.0/1 [00:01<00:00,  1.32s/it]
# ncurses-6.4          | 914 KB    | : 100% 1.0/1 [00:00<00:00,  2.23it/s]
# libgcc-ng-11.2.0     | 5.3 MB    | : 100% 1.0/1 [00:00<00:00,  2.25it/s]
# libgomp-11.2.0       | 474 KB    | : 100% 1.0/1 [00:00<00:00,  4.51it/s]
# _openmp_mutex-5.1    | 21 KB     | : 100% 1.0/1 [00:00<00:00,  5.06it/s]
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate FairnessDeepfake
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
# Collecting gensim==3.8.1
#   Using cached gensim-3.8.1-cp37-cp37m-manylinux1_x86_64.whl (24.2 MB)
# Collecting pyLDAvis==2.1.2
#   Using cached pyLDAvis-2.1.2.tar.gz (1.6 MB)
# Collecting spacy==2.2.3
#   Downloading spacy-2.2.3-cp37-cp37m-manylinux1_x86_64.whl (10.4 MB)
#      |████████████████████████████████| 10.4 MB 274 kB/s
# Collecting scikit-learn==0.23.1
#   Downloading scikit_learn-0.23.1-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 18.1 MB/s
# Collecting seaborn==0.11.0
#   Downloading seaborn-0.11.0-py3-none-any.whl (283 kB)
#      |████████████████████████████████| 283 kB 52.8 MB/s
# Collecting squarify==0.4.3
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Collecting ipykernel
#   Downloading ipykernel-6.16.2-py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 58.3 MB/s
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 48.5 MB/s
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 41.3 MB/s
# Collecting scipy
#   Downloading scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
#      |████████████████████████████████| 38.1 MB 1.2 MB/s
# Collecting smart-open>=1.8.1
#   Downloading smart_open-7.0.4-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 7.9 MB/s
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.7/site-packages (from gensim==3.8.1->-r requirements.txt (line 2)) (1.15.0)
# Collecting numpy>=1.11.3
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 43.4 MB/s
# Requirement already satisfied: wheel>=0.23.0 in /usr/local/lib/python3.7/site-packages (from pyLDAvis==2.1.2->-r requirements.txt (line 3)) (0.35.1)
# Collecting joblib>=0.8.4
#   Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#      |████████████████████████████████| 302 kB 55.8 MB/s
# Collecting jinja2>=2.7.2
#   Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 54.7 MB/s
# Collecting numexpr
#   Downloading numexpr-2.8.6-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (382 kB)
#      |████████████████████████████████| 382 kB 33.3 MB/s
# Collecting pytest
#   Downloading pytest-7.4.4-py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 58.2 MB/s
# Collecting future
#   Downloading future-1.0.0-py3-none-any.whl (491 kB)
#      |████████████████████████████████| 491 kB 57.0 MB/s
# Collecting funcy
#   Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (151 kB)
#      |████████████████████████████████| 151 kB 22.9 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from spacy==2.2.3->-r requirements.txt (line 4)) (50.3.1.post20201107)
# Collecting thinc<7.4.0,>=7.3.0
#   Downloading thinc-7.3.1-cp37-cp37m-manylinux1_x86_64.whl (2.2 MB)
#      |████████████████████████████████| 2.2 MB 45.0 MB/s
# Collecting wasabi<1.1.0,>=0.4.0
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/site-packages (from spacy==2.2.3->-r requirements.txt (line 4)) (2.24.0)
# Collecting srsly<1.1.0,>=0.1.0
#   Downloading srsly-1.0.7-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (367 kB)
#      |████████████████████████████████| 367 kB 6.4 MB/s
# Collecting blis<0.5.0,>=0.4.0
#   Downloading blis-0.4.1-cp37-cp37m-manylinux1_x86_64.whl (3.7 MB)
#      |████████████████████████████████| 3.7 MB 28.6 MB/s
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (46 kB)
#      |████████████████████████████████| 46 kB 4.2 MB/s
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting matplotlib>=2.2
#   Downloading matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 43.0 MB/s
# Collecting traitlets>=5.1.0
#   Downloading traitlets-5.9.0-py3-none-any.whl (117 kB)
#      |████████████████████████████████| 117 kB 47.5 MB/s
# Collecting nest-asyncio
#   Downloading nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Collecting ipython>=7.23.1
#   Downloading ipython-7.34.0-py3-none-any.whl (793 kB)
#      |████████████████████████████████| 793 kB 42.1 MB/s
# Collecting matplotlib-inline>=0.1
#   Downloading matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# Collecting debugpy>=1.0
#   Downloading debugpy-1.7.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 17.0 MB/s
# Collecting tornado>=6.1
#   Downloading tornado-6.2-cp37-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
#      |████████████████████████████████| 423 kB 38.4 MB/s
# Collecting packaging
#   Downloading packaging-24.0-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.0 MB/s
# Collecting jupyter-client>=6.1.12
#   Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 47.9 MB/s
# Collecting psutil
#   Downloading psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#      |████████████████████████████████| 288 kB 47.9 MB/s
# Collecting pyzmq>=17
#   Downloading pyzmq-26.0.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (908 kB)
#      |████████████████████████████████| 908 kB 48.1 MB/s
# Collecting click
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 7.8 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/site-packages (from nltk->-r requirements.txt (line 9)) (4.51.0)
# Collecting regex>=2021.8.3
#   Downloading regex-2024.4.16-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (761 kB)
#      |████████████████████████████████| 761 kB 45.2 MB/s
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      |████████████████████████████████| 229 kB 38.2 MB/s
# Collecting pytz>=2017.3
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      |████████████████████████████████| 505 kB 53.9 MB/s
# Collecting wrapt
#   Downloading wrapt-1.16.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
#      |████████████████████████████████| 77 kB 6.3 MB/s
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.2.0-py3-none-any.whl (17 kB)
# Collecting importlib-metadata>=0.12; python_version < "3.8"
#   Downloading importlib_metadata-6.7.0-py3-none-any.whl (22 kB)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting exceptiongroup>=1.0.0rc8; python_version < "3.11"
#   Downloading exceptiongroup-1.2.1-py3-none-any.whl (16 kB)
# Collecting tomli>=1.0.0; python_version < "3.11"
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting zipp>=0.5; python_version < "3.8"
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3->-r requirements.txt (line 4)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3->-r requirements.txt (line 4)) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3->-r requirements.txt (line 4)) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3->-r requirements.txt (line 4)) (3.0.4)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.38.0-py3-none-any.whl (965 kB)
#      |████████████████████████████████| 965 kB 54.3 MB/s
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 34.0 MB/s
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.5-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 36.0 MB/s
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 37.6 MB/s
# Collecting decorator
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0
#   Downloading prompt_toolkit-3.0.45-py3-none-any.whl (386 kB)
#      |████████████████████████████████| 386 kB 51.0 MB/s
# Collecting pickleshare
#   Downloading pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Collecting pexpect>4.3; sys_platform != "win32"
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.2 MB/s
# Collecting backcall
#   Downloading backcall-0.2.0-py2.py3-none-any.whl (11 kB)
# Collecting pygments
#   Downloading pygments-2.17.2-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 46.2 MB/s
# Collecting jedi>=0.16
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 49.8 MB/s
# Collecting entrypoints
#   Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Collecting jupyter-core>=4.9.2
#   Downloading jupyter_core-4.12.0-py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 6.1 MB/s
# Collecting wcwidth
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Collecting ptyprocess>=0.5
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting parso<0.9.0,>=0.8.3
#   Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 30.2 MB/s
# Building wheels for collected packages: pyLDAvis
#   Building wheel for pyLDAvis (setup.py) ... done
#   Created wheel for pyLDAvis: filename=pyLDAvis-2.1.2-py2.py3-none-any.whl size=97712 sha256=5f7dac8385f3f2c43c2230ed6441b297ca56e5223948508d8498a7966c3159e7
#   Stored in directory: /root/.cache/pip/wheels/3b/fb/41/e32e5312da9f440d34c4eff0d2207b46dc9332a7b931ef1e89
# Successfully built pyLDAvis
# Installing collected packages: numpy, scipy, wrapt, smart-open, gensim, python-dateutil, pytz, pandas, joblib, MarkupSafe, jinja2, numexpr, zipp, typing-extensions, importlib-metadata, pluggy, iniconfig, packaging, exceptiongroup, tomli, pytest, future, funcy, pyLDAvis, murmurhash, cymem, preshed, srsly, wasabi, blis, plac, thinc, catalogue, spacy, threadpoolctl, scikit-learn, fonttools, pillow, kiwisolver, cycler, pyparsing, matplotlib, seaborn, squarify, traitlets, nest-asyncio, decorator, wcwidth, prompt-toolkit, pickleshare, ptyprocess, pexpect, backcall, matplotlib-inline, pygments, parso, jedi, ipython, debugpy, tornado, pyzmq, entrypoints, jupyter-core, jupyter-client, psutil, ipykernel, click, regex, nltk
# Successfully installed MarkupSafe-2.1.5 backcall-0.2.0 blis-0.4.1 catalogue-1.0.2 click-8.1.7 cycler-0.11.0 cymem-2.0.8 debugpy-1.7.0 decorator-5.1.1 entrypoints-0.4 exceptiongroup-1.2.1 fonttools-4.38.0 funcy-2.0 future-1.0.0 gensim-3.8.1 importlib-metadata-6.7.0 iniconfig-2.0.0 ipykernel-6.16.2 ipython-7.34.0 jedi-0.19.1 jinja2-3.1.4 joblib-1.3.2 jupyter-client-7.4.9 jupyter-core-4.12.0 kiwisolver-1.4.5 matplotlib-3.5.3 matplotlib-inline-0.1.6 murmurhash-1.0.10 nest-asyncio-1.6.0 nltk-3.8.1 numexpr-2.8.6 numpy-1.21.6 packaging-24.0 pandas-1.3.5 parso-0.8.4 pexpect-4.9.0 pickleshare-0.7.5 pillow-9.5.0 plac-1.1.3 pluggy-1.2.0 preshed-3.0.9 prompt-toolkit-3.0.45 psutil-5.9.8 ptyprocess-0.7.0 pyLDAvis-2.1.2 pygments-2.17.2 pyparsing-3.1.2 pytest-7.4.4 python-dateutil-2.9.0.post0 pytz-2024.1 pyzmq-26.0.3 regex-2024.4.16 scikit-learn-0.23.1 scipy-1.7.3 seaborn-0.11.0 smart-open-7.0.4 spacy-2.2.3 squarify-0.4.3 srsly-1.0.7 thinc-7.3.1 threadpoolctl-3.1.0 tomli-2.0.1 tornado-6.2 traitlets-5.9.0 typing-extensions-4.7.1 wasabi-0.10.1 wcwidth-0.2.13 wrapt-1.16.0 zipp-3.15.0

# %%
# %cd training
# Out:
# [Errno 2] No such file or directory: 'training'
# /content/drive/.shortcut-targets-by-id/1G2cdVmYKHKDsw8sItqkKcykT_fs7die1/Project
# python: can't open file 'train.py': [Errno 2] No such file or directory

# %%
# !which python # should return /usr/local/bin/python
# !python --version
# Out:
# /usr/local/bin/python
# Python 3.7.9

# %%
# !echo $PYTHONPATH # /env/python
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.9.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.9.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# !which conda  # should return /usr/local/bin/conda
# !conda --version
# Out:
# --2024-05-29 07:01:35--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.9.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 90040905 (86M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.9.2-Linux-x86_64.sh.2’
#
# Miniconda3-py37_4.9 100%[===================>]  85.87M  46.4MB/s    in 1.8s
#
# 2024-05-29 07:01:37 (46.4 MB/s) - ‘Miniconda3-py37_4.9.2-Linux-x86_64.sh.2’ saved [90040905/90040905]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - brotlipy==0.7.0=py37h27cfd23_1003
#     - ca-certificates==2020.10.14=0
#     - certifi==2020.6.20=pyhd3eb1b0_3
#     - cffi==1.14.3=py37h261ae71_2
#     - chardet==3.0.4=py37h06a4308_1003
#     - conda-package-handling==1.7.2=py37h03888b9_0
#     - conda==4.9.2=py37h06a4308_0
#     - cryptography==3.2.1=py37h3c74f83_1
#     - idna==2.10=py_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20191231=h14c3975_1
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_1
#     - openssl==1.1.1h=h7b6447c_0
#     - pip==20.2.4=py37h06a4308_0
#     - pycosat==0.6.3=py37h27cfd23_0
#     - pycparser==2.20=py_2
#     - pyopenssl==19.1.0=pyhd3eb1b0_1
#     - pysocks==1.7.1=py37_1
#     - python==3.7.9=h7579374_0
#     - readline==8.0=h7b6447c_0
#     - requests==2.24.0=py_0
#     - ruamel_yaml==0.15.87=py37h7b6447c_1
#     - setuptools==50.3.1=py37h06a4308_1
#     - six==1.15.0=py37h06a4308_0
#     - sqlite==3.33.0=h62c20be_0
#     - tk==8.6.10=hbc83047_0
#     - tqdm==4.51.0=pyhd3eb1b0_0
#     - urllib3==1.25.11=py_0
#     - wheel==0.35.1=pyhd3eb1b0_0
#     - xz==5.2.5=h7b6447c_0
#     - yaml==0.2.5=h7b6447c_0
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   brotlipy           pkgs/main/linux-64::brotlipy-0.7.0-py37h27cfd23_1003
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.10.14-0
#   certifi            pkgs/main/noarch::certifi-2020.6.20-pyhd3eb1b0_3
#   cffi               pkgs/main/linux-64::cffi-1.14.3-py37h261ae71_2
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py37h06a4308_1003
#   conda              pkgs/main/linux-64::conda-4.9.2-py37h06a4308_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.7.2-py37h03888b9_0
#   cryptography       pkgs/main/linux-64::cryptography-3.2.1-py37h3c74f83_1
#   idna               pkgs/main/noarch::idna-2.10-py_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20191231-h14c3975_1
#   libffi             pkgs/main/linux-64::libffi-3.3-he6710b0_2
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_1
#   openssl            pkgs/main/linux-64::openssl-1.1.1h-h7b6447c_0
#   pip                pkgs/main/linux-64::pip-20.2.4-py37h06a4308_0
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py37h27cfd23_0
#   pycparser          pkgs/main/noarch::pycparser-2.20-py_2
#   pyopenssl          pkgs/main/noarch::pyopenssl-19.1.0-pyhd3eb1b0_1
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py37_1
#   python             pkgs/main/linux-64::python-3.7.9-h7579374_0
#   readline           pkgs/main/linux-64::readline-8.0-h7b6447c_0
#   requests           pkgs/main/noarch::requests-2.24.0-py_0
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py37h7b6447c_1
#   setuptools         pkgs/main/linux-64::setuptools-50.3.1-py37h06a4308_1
#   six                pkgs/main/linux-64::six-1.15.0-py37h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.33.0-h62c20be_0
#   tk                 pkgs/main/linux-64::tk-8.6.10-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.51.0-pyhd3eb1b0_0
#   urllib3            pkgs/main/noarch::urllib3-1.25.11-py_0
#   wheel              pkgs/main/noarch::wheel-0.35.1-pyhd3eb1b0_0
#   xz                 pkgs/main/linux-64::xz-5.2.5-h7b6447c_0
#   yaml               pkgs/main/linux-64::yaml-0.2.5-h7b6447c_0
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# /usr/local/bin/conda
# conda 4.9.2

# %%
# !python --version

# list the files/directories in the current directory
# !ls /usr/local/lib/python3.10/dist-packages
# requirements.txt 생성
p = """
gensim==3.8.1
pyLDAvis==2.1.2
spacy==2.2.3
scikit-learn==0.23.1
seaborn==0.11.0
squarify==0.4.3
ipykernel
nltk
pandas
scipy
"""

c = """text_file = open("requirements.txt", "w+");text_file.write(p);text_file.close()"""

exec(c)
# Out:
# Python 3.7.9
# ls: cannot access '/usr/local/lib/python3.7/dist-packages': No such file or directory

# %%
# %%bash
# source activate myenv
#
# python
# import sys
# # some simple python commands
# sys.path.append('/usr/local/lib/python3.10/site-packages')
# print(sys.path)
#
# print("Python version")
# print(sys.version)
# Out:
# ['', '/usr/local/lib/python37.zip', '/usr/local/lib/python3.7', '/usr/local/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/site-packages', '/usr/local/lib/python3.10/site-packages']
# Python version
# 3.7.9 (default, Aug 31 2020, 12:42:55)
# [GCC 7.3.0]
# Could not find conda environment: myenv
# You can list all discoverable environments with `conda info --envs`.

# %%
# !conda create -n envname python==3.7
# Out:
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/envname
#
#   added / updated specs:
#     - python==3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     libedit-3.1.20230828       |       h5eee18b_0         179 KB
#     libffi-3.2.1               |    hf484d3e_1007          48 KB
#     openssl-1.0.2u             |       h7b6447c_0         2.2 MB
#     pip-22.3.1                 |   py37h06a4308_0         2.7 MB
#     python-3.7.0               |       h6e4f718_3        27.2 MB
#     readline-7.0               |       h7b6447c_5         324 KB
#     setuptools-65.6.3          |   py37h06a4308_0         1.1 MB
#     wheel-0.38.4               |   py37h06a4308_0          63 KB
#     ------------------------------------------------------------
#                                            Total:        34.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2024.3.11-h06a4308_0
#   certifi            pkgs/main/linux-64::certifi-2022.12.7-py37h06a4308_0
#   libedit            pkgs/main/linux-64::libedit-3.1.20230828-h5eee18b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hf484d3e_1007
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   openssl            pkgs/main/linux-64::openssl-1.0.2u-h7b6447c_0
#   pip                pkgs/main/linux-64::pip-22.3.1-py37h06a4308_0
#   python             pkgs/main/linux-64::python-3.7.0-h6e4f718_3
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   setuptools         pkgs/main/linux-64::setuptools-65.6.3-py37h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.33.0-h62c20be_0
#   tk                 pkgs/main/linux-64::tk-8.6.14-h39e8969_0
#   wheel              pkgs/main/linux-64::wheel-0.38.4-py37h06a4308_0
#   xz                 pkgs/main/linux-64::xz-5.4.6-h5eee18b_1
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_1
#
#
# Proceed ([y]/n)? y
#
#
# Downloading and Extracting Packages
# openssl-1.0.2u       | 2.2 MB    | : 100% 1.0/1 [00:00<00:00,  3.26it/s]
# libedit-3.1.20230828 | 179 KB    | : 100% 1.0/1 [00:00<00:00,  5.85it/s]
# readline-7.0         | 324 KB    | : 100% 1.0/1 [00:00<00:00,  5.34it/s]
# pip-22.3.1           | 2.7 MB    | : 100% 1.0/1 [00:00<00:00,  2.84it/s]
# python-3.7.0         | 27.2 MB   | : 100% 1.0/1 [00:01<00:00,  1.74s/it]
# setuptools-65.6.3    | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.96it/s]
# certifi-2022.12.7    | 150 KB    | : 100% 1.0/1 [00:00<00:00,  5.88it/s]
# libffi-3.2.1         | 48 KB     | : 100% 1.0/1 [00:00<00:00,  6.20it/s]
# wheel-0.38.4         | 63 KB     | : 100% 1.0/1 [00:00<00:00,  5.84it/s]
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate envname
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !source activate envname && conda env list
# Out:
# # conda environments:
# #
# base                     /usr/local
# FairnessDeepfake         /usr/local/envs/FairnessDeepfake
# envname               *  /usr/local/envs/envname

# %%
# !conda install --channel conda-forge --file requirements.txt --yes
# Out:
# - WARNING conda.models.version:get_matcher(545): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 24.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - gensim==3.8.1
#     - ipykernel
#     - nltk
#     - pandas
#     - pyldavis==2.1.2
#     - scikit-learn==0.23.1
#     - scipy
#     - seaborn==0.11.0
#     - spacy==2.2.3
#     - squarify==0.4.3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ipykernel-6.15.0           |     pyh210e3f2_0          96 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          96 KB
#
# The following packages will be UPDATED:
#
#   ipykernel          conda-forge/linux-64::ipykernel-6.14.~ --> conda-forge/noarch::ipykernel-6.15.0-pyh210e3f2_0 None
#
#
#
# Downloading and Extracting Packages
# ipykernel-6.15.0     | 96 KB     | : 100% 1.0/1 [00:00<00:00,  9.30it/s]
# done
# done
# done
# Retrieving notices: ...working... done

# %% [markdown]
# ###refer: https://aimb.tistory.com/179
